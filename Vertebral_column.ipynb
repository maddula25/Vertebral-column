# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("/content/vertebral.csv")

# %%
data.plot(kind='box')
# Out:
# <Axes: >

# %%
import numpy as np
from scipy import stats

data1 = np.array(data['pelvic_tilt'],data['class'])

q1 = np.percentile(data1, 25)
q3 = np.percentile(data1, 75)
iqr = q3 - q1
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr
outliers = np.where((data1< lower_fence) | (data1 > upper_fence))

print("Outliers of array ",data1,"is : \n", data1[outliers])
# Out:
# Outliers of array  [22.55258597 10.06099147 22.21848205 24.65287791 9.652074879 13.92190658
#  15.86433612 10.75561143 13.5337531 5.010884121 13.04097405 17.71581923
#  19.96455616 20.46082824 24.1888846 12.53799164 20.36250706 3.14466948
#  13.44474904 12.25407408 14.17795853 21.06233245 24.41380271 13.06959759
#  22.75875277 26.65048856 10.75945357 16.5088837 21.93114655 24.89199889
#  15.40221253 11.07904664 17.44383762 12.98644139 31.99824445 7.82622134
#  6.989378081 19.44325311 28.84744756 19.01156052 11.7016723 8.39503589
#  19.23064334 26.32784484 16.2979149 23.01516931 22.22778399 16.57736351
#  17.97778407 17.89940172 20.44011836 41.55733141 29.76012218 11.91744524
#  17.32120599 13.27738491 7.467468964 15.35151393 19.66314572 14.93072472
#  32.05310438 32.70443487 9.433234213 21.38064464 21.93618556 41.28630543
#  22.1817978 19.33979889 18.94617604 -0.261499046 17.38519079 32.9281677
#  33.02117462 20.09515673 23.07771056 39.82272448 36.04301632 7.667044186
# ...

# %%
#data1 = np.array(data['degree_spondylolisthesis'])
#101.7190919 145.3781432 110.8607824 148.7537109 418.5430821 118.3533701
 #104.8592474 124.9844057 117.3146829 101.2187828]
 #[129.8340406 118.1446548 115.9232606] #pelvic incidence
 #[41.55733141 41.28630543 39.82272448 42.39620445 -6.55494835 48.06953097
 #39.84466878 48.90365265 42.68919513 49.4318636  40.30376567 41.93368293
 #46.55005318 #pelvic tilt
  #[121.4295656] #sacral slope
  #[ 84.24141517 148.5255624  151.8398566  163.0710405   82.45603817
  #81.0245406   70.08257486  78.99945411 157.848799    88.43424213
 #147.8946372 ] #pelvic radius
 # [125.7423855] #lumbar lordosis angle

# %%
data.describe()
# Out:
#        Unnamed: 0  pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  \
# count  310.000000        310.000000   310.000000             310.000000
# mean   155.500000         60.496653    17.542822              51.930930
# std     89.633513         17.236520    10.008330              18.554064
# min      1.000000         26.147921    -6.554948              14.000000
# 25%     78.250000         46.430294    10.667069              37.000000
# 50%    155.500000         58.691038    16.357689              49.562398
# 75%    232.750000         72.877696    22.120395              63.000000
# max    310.000000        129.834041    49.431864             125.742385
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    310.000000     310.000000                310.000000
# mean      42.953831     117.920655                 26.296694
# std       13.423102      13.317377                 37.559027
# min       13.366931      70.082575                -11.058179
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(y=data['degree_spondylolisthesis'],x=data['class'])
# Out:
# <Axes: xlabel='class', ylabel='degree_spondylolisthesis'>

# %%
sns.boxplot(y=data['lumbar_lordosis_angle'],x=data['class'])
# Out:
# <Axes: xlabel='class', ylabel='lumbar_lordosis_angle'>

# %%
sns.boxplot(y=data['pelvic_incidence'],x=data['class'])
# Out:
# <Axes: xlabel='class', ylabel='pelvic_incidence'>

# %%
sns.boxplot(y=data['pelvic_tilt'],x=data['class'])
# Out:
# <Axes: xlabel='class', ylabel='pelvic_tilt'>

# %%
sns.boxplot(y=data['pelvic_radius'],x=data['class'])
# Out:
# <Axes: xlabel='class', ylabel='pelvic_radius'>

# %%
sns.boxplot(y=data['sacral_slope'],x=data['class'])
# Out:
# <Axes: xlabel='class', ylabel='sacral_slope'>

# %%
plt.boxplot(data[data['class']=='Spondylolisthesis']['pelvic_incidence'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7de7c6ce7100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7de7c6ce7640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7de7c6ce6e60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7de7c6ce7b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7de7c6ce7e20>],
#  'means': []}

# %%
import numpy as np
from scipy import stats

d1 = np.array(data[data['class']=='Spondylolisthesis']['lumbar_lordosis_angle'])

q1 = np.percentile(data1, 25)
q3 = np.percentile(data1, 75)
iqr = q3 - q1
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr
outliers = np.where((d1< lower_fence) | (d1 > upper_fence))


print("Outliers of array ",data1,"is : \n", d1[outliers])
# Out:
# Outliers of array  [22.55258597 10.06099147 22.21848205 24.65287791 9.652074879 13.92190658
#  15.86433612 10.75561143 13.5337531 5.010884121 13.04097405 17.71581923
#  19.96455616 20.46082824 24.1888846 12.53799164 20.36250706 3.14466948
#  13.44474904 12.25407408 14.17795853 21.06233245 24.41380271 13.06959759
#  22.75875277 26.65048856 10.75945357 16.5088837 21.93114655 24.89199889
#  15.40221253 11.07904664 17.44383762 12.98644139 31.99824445 7.82622134
#  6.989378081 19.44325311 28.84744756 19.01156052 11.7016723 8.39503589
#  19.23064334 26.32784484 16.2979149 23.01516931 22.22778399 16.57736351
#  17.97778407 17.89940172 20.44011836 41.55733141 29.76012218 11.91744524
#  17.32120599 13.27738491 7.467468964 15.35151393 19.66314572 14.93072472
#  32.05310438 32.70443487 9.433234213 21.38064464 21.93618556 41.28630543
#  22.1817978 19.33979889 18.94617604 -0.261499046 17.38519079 32.9281677
#  33.02117462 20.09515673 23.07771056 39.82272448 36.04301632 7.667044186
# ...

# %%
#[151.8398566  163.0710405   70.08257486 157.848799  ] #pelvic_radius
#[145.3781432 110.8607824 148.7537109 418.5430821 118.3533701 124.9844057 117.3146829] degree spondylolistheisis
#[ 78.79405249  77.19573393 121.4295656   79.69515353  78.40782459 19.29004622  21.25050551] #sacral slope
#[129.8340406 118.1446548 115.9232606]pelvic incidence
#[125.7423855] lumbar_lordosis angle

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    Unnamed: 0  pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  \
# 0           1         63.027817    22.552586              39.609117
# 1           2         39.056951    10.060991              25.015378
# 2           3         68.832021    22.218482              50.092194
# 3           4         69.297008    24.652878              44.311238
# 4           5         49.712859     9.652075              28.317406
#
#    sacral_slope  pelvic_radius  degree_spondylolisthesis   class
# 0     40.475232      98.672917                 -0.254400  Hernia
# 1     28.995960     114.405425                  4.564259  Hernia
# 2     46.613539     105.985135                 -3.530317  Hernia
# 3     44.644130     101.868495                 11.211523  Hernia
# 4     40.060784     108.168725                  7.918501  Hernia

# %%
df[df['degree_spondylolisthesis']==145.3781432].index.values
# Out:
# array([75])

# %%
df[df['pelvic_radius']==151.8398566].index.values
# Out:
# array([83])

# %%
df[df['pelvic_radius']==163.0710405].index.values
# Out:
# array([85])

# %%
df[df['pelvic_radius']==70.08257486].index.values
# Out:
# array([167])

# %%
#[151.8398566  163.0710405   70.08257486 157.848799  ] #pelvic_radius
df[df['pelvic_radius']==157.848799 ].index.values
# Out:
# array([180])

# %%
df[df['degree_spondylolisthesis']==145.3781432].index.values
# Out:
# array([75])

# %%
df[df['degree_spondylolisthesis']==110.8607824].index.values
# Out:
# array([76])

# %%
df[df['degree_spondylolisthesis']==148.7537109].index.values
# Out:
# array([95])

# %%
df[df['degree_spondylolisthesis']==418.5430821].index.values
# Out:
# array([115])

# %%
df[df['degree_spondylolisthesis']==118.3533701].index.values
# Out:
# array([141])

# %%
df[df['degree_spondylolisthesis']==124.9844057].index.values
# Out:
# array([192])

# %%
df[df['degree_spondylolisthesis']==117.3146829].index.values
# Out:
# array([197])

# %%
df[df['sacral_slope']==78.79405249].index.values
# Out:
# array([94])

# %%
df[df['sacral_slope']==77.19573393].index.values
# Out:
# array([96])

# %%
df[df['sacral_slope']==121.4295656].index.values
# Out:
# array([115])

# %%
df[df['sacral_slope']==79.69515353].index.values
# Out:
# array([162])

# %%
df[df['sacral_slope']==78.40782459].index.values
# Out:
# array([163])

# %%
df[df['sacral_slope']==19.29004622].index.values
# Out:
# array([179])

# %%
df[df['sacral_slope']==21.25050551].index.values
# Out:
# array([197])

# %%
df[df['pelvic_incidence']==129.8340406].index.values
# Out:
# array([115])

# %%
df[df['pelvic_incidence']==118.1446548].index.values
# Out:
# array([162])

# %%
df[df['pelvic_incidence']==115.9232606].index.values
# Out:
# array([163])

# %%
df[df['lumbar_lordosis_angle']==125.7423855].index.values
# Out:
# array([197])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                310 non-null    int64
#  1   pelvic_incidence          310 non-null    float64
#  2   pelvic_tilt               310 non-null    float64
#  3   lumbar_lordosis_angle     310 non-null    float64
#  4   sacral_slope              310 non-null    float64
#  5   pelvic_radius             310 non-null    float64
#  6   degree_spondylolisthesis  310 non-null    float64
#  7   class                     310 non-null    object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 19.5+ KB

# %%
df2=df.drop([75,83,85,167,180,76,95,115,141,192,197,94,96,162,163,179,197])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                294 non-null    int64
#  1   pelvic_incidence          294 non-null    float64
#  2   pelvic_tilt               294 non-null    float64
#  3   lumbar_lordosis_angle     294 non-null    float64
#  4   sacral_slope              294 non-null    float64
#  5   pelvic_radius             294 non-null    float64
#  6   degree_spondylolisthesis  294 non-null    float64
#  7   class                     294 non-null    int64
# dtypes: float64(6), int64(2)
# memory usage: 20.7 KB

# %%
df2.describe()
# Out:
#        Unnamed: 0  pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  \
# count  294.000000        294.000000   294.000000             294.000000
# mean   156.765306         59.375548    16.954944              51.143499
# std     91.303582         15.955006     9.400392              18.046332
# min      1.000000         26.147921    -6.554948              14.000000
# 25%     74.250000         46.378131    10.570471              36.649639
# 50%    156.500000         57.216398    15.916840              48.118403
# 75%    236.750000         71.850967    21.371814              62.381675
# max    310.000000         95.480229    48.069531             100.744220
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    294.000000     294.000000                294.000000
# mean      42.420604     117.390864                 22.140501
# std       12.009056      12.058082                 26.391544
# min       13.366931      78.999454                -11.058179
# ...

# %%
df2.to_excel('bpl.xlsx', index=False)

# %%
df2.plot(kind='box')
# Out:
# <Axes: >

# %%
df2.head()
# Out:
#    Unnamed: 0  pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  \
# 0           1         63.027817    22.552586              39.609117
# 1           2         39.056951    10.060991              25.015378
# 2           3         68.832021    22.218482              50.092194
# 3           4         69.297008    24.652878              44.311238
# 4           5         49.712859     9.652075              28.317406
#
#    sacral_slope  pelvic_radius  degree_spondylolisthesis   class
# 0     40.475232      98.672917                 -0.254400  Hernia
# 1     28.995960     114.405425                  4.564259  Hernia
# 2     46.613539     105.985135                 -3.530317  Hernia
# 3     44.644130     101.868495                 11.211523  Hernia
# 4     40.060784     108.168725                  7.918501  Hernia

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <ipython-input-102-6c71ac866e2e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df2['class']=le.fit_transform(df2['class'])

# %%
df2.head()
# Out:
#    Unnamed: 0  pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  \
# 0           1         63.027817    22.552586              39.609117
# 1           2         39.056951    10.060991              25.015378
# 2           3         68.832021    22.218482              50.092194
# 3           4         69.297008    24.652878              44.311238
# 4           5         49.712859     9.652075              28.317406
#
#    sacral_slope  pelvic_radius  degree_spondylolisthesis  class
# 0     40.475232      98.672917                 -0.254400      0
# 1     28.995960     114.405425                  4.564259      0
# 2     46.613539     105.985135                 -3.530317      0
# 3     44.644130     101.868495                 11.211523      0
# 4     40.060784     108.168725                  7.918501      0

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
from scipy.stats import spearmanr

# %%
spearmanr(df2['pelvic_tilt'],df2['lumbar_lordosis_angle'])
# Out:
# SignificanceResult(statistic=0.3829869220182686, pvalue=1.0468914977281135e-11)

# %%
spearmanr(df2['pelvic_tilt'],df2['degree_spondylolisthesis'])
# Out:
# SignificanceResult(statistic=0.3575821396991723, pvalue=2.6988081683566336e-10)

# %%
spearmanr(df2['lumbar_lordosis_angle'],df2['sacral_slope'])
# Out:
# SignificanceResult(statistic=0.7347106969733891, pvalue=3.9060889225917733e-51)

# %%
spearmanr(df2['lumbar_lordosis_angle'],df2['degree_spondylolisthesis'])
# Out:
# SignificanceResult(statistic=0.677172222040856, pvalue=8.60082228039047e-41)

# %%
spearmanr(df2['sacral_slope'],df2['degree_spondylolisthesis'])
# Out:
# SignificanceResult(statistic=0.5717110275907139, pvalue=6.496951941603618e-27)

# %%
spearmanr(df2['pelvic_radius'],df2['lumbar_lordosis_angle'])
# Out:
# SignificanceResult(statistic=-0.1752152099449273, pvalue=0.0025708665037177817)

# %%
pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
data=df2

# %%
y=df2['class']
x=df2.drop('class',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
clf=LazyClassifier(verbose=0,ignore_warnings=True,custom_metric=None)
models,predictions=clf.fit(x_train,x_test,y_train,y_test)
# Out:
#  69%|██████▉   | 20/29 [00:01<00:00, 19.65it/s]/usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# 100%|██████████| 29/29 [00:02<00:00, 12.27it/s]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00    None      1.00
# ExtraTreesClassifier               0.98               0.98    None      0.98
# SVC                                0.98               0.98    None      0.98
# RandomForestClassifier             0.98               0.98    None      0.98
# LogisticRegression                 0.98               0.98    None      0.98
# KNeighborsClassifier               0.98               0.98    None      0.98
# GaussianNB                         0.98               0.98    None      0.98
# LGBMClassifier                     0.98               0.98    None      0.98
# ExtraTreeClassifier                0.98               0.98    None      0.98
# LabelPropagation                   0.97               0.97    None      0.97
# LabelSpreading                     0.97               0.97    None      0.97
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=50,criterion='entropy',random_state=10)

# %%
fit=model.fit(x_train,y_train)

# %%
pred=fit.predict(x_train)

# %%
from sklearn.metrics._plot.confusion_matrix import confusion_matrix
confusion_matrix(pred,y_train)
# Out:
# array([[41,  0,  0],
#        [ 0, 65,  0],
#        [ 0,  0, 99]])

# %%
from sklearn.metrics import classification_report
print(classification_report(pred,y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        65
#            2       1.00      1.00      1.00        99
#
#     accuracy                           1.00       205
#    macro avg       1.00      1.00      1.00       205
# weighted avg       1.00      1.00      1.00       205

# %%
pred2=fit.predict(x_test)

# %%
confusion_matrix(pred2,y_test)
# Out:
# array([[19,  0,  1],
#        [ 0, 33,  1],
#        [ 0,  2, 33]])

# %%
print(classification_report(pred2,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        20
#            1       0.94      0.97      0.96        34
#            2       0.94      0.94      0.94        35
#
#     accuracy                           0.96        89
#    macro avg       0.96      0.95      0.96        89
# weighted avg       0.96      0.96      0.96        89

# %%
from sklearn.tree import plot_tree

# %%
z=np.array([38.50,16.96,35.11,21.54,127.63,7.98])
z.reshape
# Out:
# <function ndarray.reshape>
